# %% [markdown]
# # Jan Golob: PROJEKT
# Zajel sem podatke z interneta, zdaj pa jih bom obdelal.
#
# ## Uvod
# Izbral sem na IMDB-ju najpopularjnejših 1000 filmov ki so prišli v kina med letoma 2004 in 2015.
# Za tako omejitev sem se odločil, ker veliko filmov, ki so prišli v letu 2015 še ni bilo objavljenih na piratskih straneh v vseh formatih, in zato to lahko vpliva na rezultate.
# Leto 2004 pa sem izbral zato da bi imel ravno 10 let okvira za filme.
#
# ## Hipoteza
# Predvidevam da:
# * Največ bo filmov, ki so prišli ven leta 2014
# * Najpopularjnejši žanr na Piratebayu bo znanstvena fantastika in akcija
# * Filmi z boljšo oceno bodo bolj zastopani na Piratebayu

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

original = pd.read_csv("Podatki_Projekt.csv")
zanri = pd.read_csv("Zanr_Projekt2.csv")
#, index_col='Id'
# fax "U:\Python\Projekt.2\Projekt-IMDB-PirateBay-master\Podatki_Projekt.csv"
# dom "C:\DATA\F.M.F\2.letnik\Pro2\Podatki_Projekt.csv"

pd.options.display.max_rows = 10
#plt.style.use('ggplot')
#plt.rcParams['figure.figsize'] = (15, 5)

# %%
original
#podatki so bili zajeti pon 22.2.2016
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>ime</th>
#       <th>leto</th>
#       <th>IMDB_ocena</th>
#       <th>IMDB_glasovi</th>
#       <th>PBay_sejalci</th>
#       <th>PBay_pijavke</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Interstellar</td>
#       <td>2014</td>
#       <td>8.6</td>
#       <td>843711</td>
#       <td>4597</td>
#       <td>391</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>X-Men Origins: Wolverine</td>
#       <td>2009</td>
#       <td>6.7</td>
#       <td>339839</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>Prisoners</td>
#       <td>2013</td>
#       <td>8.1</td>
#       <td>356010</td>
#       <td>746</td>
#       <td>109</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
# ...

# %%
original.mean()
# Out:
# leto              2010.165992
# IMDB_ocena           6.783401
# IMDB_glasovi    173937.293522
# PBay_sejalci       319.840081
# PBay_pijavke        43.917004
# dtype: float64

# %%
raw = original[original.PBay_sejalci != 0]
raw
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>ime</th>
#       <th>leto</th>
#       <th>IMDB_ocena</th>
#       <th>IMDB_glasovi</th>
#       <th>PBay_sejalci</th>
#       <th>PBay_pijavke</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Interstellar</td>
#       <td>2014</td>
#       <td>8.6</td>
#       <td>843711</td>
#       <td>4597</td>
#       <td>391</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>Prisoners</td>
#       <td>2013</td>
#       <td>8.1</td>
#       <td>356010</td>
#       <td>746</td>
#       <td>109</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>Kingsman: The Secret Service</td>
#       <td>2014</td>
#       <td>7.8</td>
#       <td>357774</td>
#       <td>2795</td>
#       <td>459</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
# ...

# %% [raw]
# Ker nekateri filmi nimajo Torentov na Piratebayu sem jih odstranil s seznama, da ne bi imel kakšnih "problemov" z njimi. (odstranil sem 9.8% filmov)

# %%
#Poglejmo povprečje zajetih podatkov
((100*raw.mean())//1)/100
# Out:
# leto              2010.22
# IMDB_ocena           6.79
# IMDB_glasovi    178567.72
# PBay_sejalci       349.17
# PBay_pijavke        47.94
# dtype: float64

# %%
((100 * original[original.PBay_sejalci == 0].mean())//1)/100
# Out:
# leto              2009.49
# IMDB_ocena           6.63
# IMDB_glasovi    123448.80
# PBay_sejalci         0.00
# PBay_pijavke         0.01
# dtype: float64

# %% [raw]
# Vidimo da imajo filmi ki jih nismo našli na Piratebayu slabo oceno in povprečno število glasov

# %%
raw.groupby('leto').size()
# Out:
# leto
# 2004     60
# 2005     50
# 2006     51
# 2007     58
# 2008     61
#        ...
# 2010     75
# 2011     90
# 2012     84
# 2013    126
# 2014    186
# dtype: int64

# %%
raw.groupby('leto').size().plot(kind='bar')

# %% [raw]
# Tukaj vidimo grafe, ki prikazujejo razvrstitev najpopularnejših filmov na IMDB ter "popularnosti" njihovih torrentov na Piratebay-u.
# Opazimo da ocene in glasovi na IMDB z leti padajo.
# Kot Vidimo je več filmov v zadnjih letih, za te filme je v povprečju tudi več torentov.

# %%
raw.groupby('leto').mean().plot(subplots=True, kind="bar", legend=False, layout=(1,4), alpha=0.5, figsize=(20, 5),grid=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000147E1AB3F28>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000147E335E0B8>]], dtype=object)

# %%
ocena = original['IMDB_ocena'].idxmax()
glasovi = original['IMDB_glasovi'].idxmax()
sejalci = raw['PBay_sejalci'].idxmax()
pijavke = raw['PBay_pijavke'].idxmax()
top = [ocena ,glasovi ,sejalci ,pijavke]
x = original.loc[top,:]
y = pd.DataFrame({'Naj' : pd.Series(["IMDB ocena","IMDB glasovi","Sejalci","Pijavke"], index=top)})
y.join(x).drop_duplicates()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Naj</th>
#       <th>Id</th>
#       <th>ime</th>
#       <th>leto</th>
#       <th>IMDB_ocena</th>
#       <th>IMDB_glasovi</th>
#       <th>PBay_sejalci</th>
#       <th>PBay_pijavke</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>Pijavke</td>
#       <td>5</td>
#       <td>Inception</td>
#       <td>2010</td>
#       <td>8.8</td>
#       <td>1389686</td>
#       <td>2558</td>
#       <td>500</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>IMDB ocena</td>
#       <td>9</td>
#       <td>The Dark Knight</td>
#       <td>2008</td>
#       <td>9.0</td>
#       <td>1587975</td>
#       <td>324</td>
#       <td>102</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>IMDB glasovi</td>
#       <td>9</td>
#       <td>The Dark Knight</td>
#       <td>2008</td>
#       <td>9.0</td>
#       <td>1587975</td>
# ...

# %% [raw]
# Tukaj filme, ki imajo najvišjo IMDB oceno, največ glasov na IMDB, ter največ sejalcev in pijavk na PirateBay-u

# %%
zanri
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>st</th>
#       <th>zanr</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>adventure</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>drama</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>sci_fi</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>action</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>adventure</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2915</th>
#       <td>998</td>
#       <td>drama</td>
#     </tr>
#     <tr>
#       <th>2916</th>
#       <td>998</td>
#       <td>sport</td>
#     </tr>
#     <tr>
#       <th>2917</th>
#       <td>999</td>
#       <td>action</td>
#     </tr>
#     <tr>
# ...

# %%
raw_z = zanri.join(raw ,on='st',how='inner')
raw_z.groupby("zanr").mean()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>st</th>
#       <th>leto</th>
#       <th>IMDB_ocena</th>
#       <th>IMDB_glasovi</th>
#       <th>PBay_sejalci</th>
#       <th>PBay_pijavke</th>
#     </tr>
#     <tr>
#       <th>zanr</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>action</th>
#       <td>437.283582</td>
#       <td>2010.150943</td>
#       <td>6.634340</td>
#       <td>236829.800000</td>
#       <td>442.120755</td>
#       <td>66.000000</td>
#     </tr>
#     <tr>
#       <th>adventure</th>
#       <td>423.233945</td>
#       <td>2009.925926</td>
#       <td>6.774074</td>
#       <td>250980.263889</td>
#       <td>506.328704</td>
#       <td>73.125000</td>
#     </tr>
#     <tr>
#       <th>animation</th>
#       <td>516.837209</td>
#       <td>2010.627907</td>
# ...

# %%
raw_z.groupby('zanr').size().sort_values(ascending=False)
# Out:
# zanr
# drama        440
# thriller     293
# comedy       277
# action       268
# adventure    218
#             ...
# history       32
# sport         32
# music         19
# musical       17
# western       10
# dtype: int64

# %%
raw_z.groupby('zanr').mean().sort_values(['PBay_sejalci', 'PBay_pijavke'],ascending=False)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>st</th>
#       <th>leto</th>
#       <th>IMDB_ocena</th>
#       <th>IMDB_glasovi</th>
#       <th>PBay_sejalci</th>
#       <th>PBay_pijavke</th>
#     </tr>
#     <tr>
#       <th>zanr</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>musical</th>
#       <td>448.823529</td>
#       <td>2010.235294</td>
#       <td>6.858824</td>
#       <td>126089.235294</td>
#       <td>620.352941</td>
#       <td>68.000000</td>
#     </tr>
#     <tr>
#       <th>sci_fi</th>
#       <td>394.291667</td>
#       <td>2010.401408</td>
#       <td>6.825352</td>
#       <td>269766.591549</td>
#       <td>535.415493</td>
#       <td>76.514085</td>
#     </tr>
#     <tr>
#       <th>animation</th>
#       <td>516.837209</td>
#       <td>2010.627907</td>
# ...

# %%
raw_z[['IMDB_glasovi','PBay_sejalci','PBay_pijavke','zanr']].groupby('zanr').sum().sort_values(['PBay_sejalci', 'PBay_pijavke'],ascending=False)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>IMDB_glasovi</th>
#       <th>PBay_sejalci</th>
#       <th>PBay_pijavke</th>
#     </tr>
#     <tr>
#       <th>zanr</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>drama</th>
#       <td>68681178</td>
#       <td>140181</td>
#       <td>18492</td>
#     </tr>
#     <tr>
#       <th>action</th>
#       <td>62759897</td>
#       <td>117162</td>
#       <td>17490</td>
#     </tr>
#     <tr>
#       <th>adventure</th>
#       <td>54211737</td>
#       <td>109367</td>
#       <td>15795</td>
#     </tr>
#     <tr>
#       <th>thriller</th>
#       <td>53574560</td>
#       <td>95371</td>
#       <td>13464</td>
#     </tr>
#     <tr>
#       <th>comedy</th>
#       <td>40748110</td>
#       <td>87544</td>
#       <td>11103</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
# ...

# %%
raw.plot(x='IMDB_glasovi',y='PBay_sejalci', kind='scatter', c='leto', figsize=(15,4), alpha=0.35, linewidths=2, grid=True, )
#Graf ki kaže povezanost med sejalci na Piratebayu in popularnostjo na IMDB
#x os zaradi neznanega razloga ne kaže svoje oznake

# %%
raw.plot(x='IMDB_glasovi',y='PBay_sejalci', kind='scatter',  figsize=(15,4), alpha=0.35, linewidths=2, grid=True, logy=True, logx=True)

# %%
raw.plot(x='IMDB_ocena',y='PBay_sejalci', kind='scatter', figsize=(15,4), alpha=0.35, linewidths=2, grid=True )

# %% [markdown]
# Opazimo da so imajo filmi z dobro oceno veliko sejalcev. Prav tako opazimo da jih imajo filmi z oceno 6 tudi presenetljivo veliko ker so to popularni filmi, lahko to pripišemo tako imenovanemu "tako slabo da je dobro" efektu.

# %%
raw_z[['PBay_sejalci','PBay_pijavke','zanr']].groupby('zanr').mean().plot(subplots=True, kind="bar", legend=False, layout=(1,2), alpha=0.75, figsize=(30, 5), fontsize=17, grid=True)
# Koliko ima v povprečju žanr sejalcev in
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000147E37A9128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000147E384A080>]], dtype=object)

# %%
raw_z[['PBay_sejalci','PBay_pijavke','zanr']].groupby('zanr').sum().plot(subplots=True, kind="bar", legend=False,fontsize=17, layout=(1,2), alpha=0.75, figsize=(30, 5),  grid=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000147E380D2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000147E39E4BE0>]], dtype=object)

# %% [markdown]
# Kot vidimo je žanr ki ima največ povprečnih sejalcev muzikal, tisti z največ pijavkami je znanstvena fantastika. Najbolj zastopan med torenti pa je žanr drama, sledita mu akcija in avantura.

# %% [raw]
# ## Zaključek:
# * Na Piratebayu je več "mladih" filmov kot "starejših"
# * Filmi ki jih na Piratebayu ni imajo v povprečju slabo oceno
# * Batman:vitez teme je na IMDB najpopularjenši film obdobja 2004-2014
# * Film Frozen ima največ sejalcev
# * Med popularnostjo filma na IMDB in na Piratebay obstaja povezava
# * Lahko sklepamo da obstaja "tako slabo da je dobro" efekt.
# * Žanr z največ povprečnimi sejalci je Muzikal in ne znanstvena fantastika (čeprav je na močnem drugem mestu)
# * Žanr najbolj zastopan na Piratebayu je drama in ne akcija (čeprav je na močnem drugem mestu)
