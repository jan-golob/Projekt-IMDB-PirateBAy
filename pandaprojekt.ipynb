# %% [markdown]
# # Jan Golob: PROJEKT
#
# To je moj projekt
# Zajel sem podatke z interneta, zdaj pa jih bom obdelal.

# %%
import pandas as pd
import matplotlib.pyplot as plt

original = pd.read_csv("U:\Python\Projekt.2\Projekt-IMDB-PirateBay-master\Podatki_Projekt.csv", index_col='Id')
#, index_col='Id'

pd.options.display.max_rows = 20
plt.style.use('ggplot')

# %%
original
# Out:
#                               ime  leto  IMDB_ocena  IMBD_glasovi  \
# Id
# 0                    Interstellar  2014         8.6        843711
# 1        X-Men Origins: Wolverine  2009         6.7        339839
# 2                       Prisoners  2013         8.1        356010
# 3    Kingsman: The Secret Service  2014         7.8        357774
# 4         The Wolf of Wall Street  2013         8.2        717893
# 5                       Inception  2010         8.8       1389686
# 6         Guardians of the Galaxy  2014         8.1        615460
# 7            Inglourious Basterds  2009         8.3        834631
# 8               The Green Inferno  2013         5.5         16039
# 9                 The Dark Knight  2008         9.0       1587975
# ..                            ...   ...         ...           ...
# 990                  The Way Back  2010         7.3         84432
# 991        The Inbetweeners Movie  2011         6.8         61213
# ...

# %% [raw]
# Izbral sem leta filme ki so prišli v kina med letoma 2004 in 2015, za tako omejitev sem se odločil, ker veliko filmov, ki so prišli v letu 2015 še ni bilo objavljenih na piratskih straneh v vseh formatih, in zato to lahko vpliva na rezultate.
# Leto 2004 pa sem izbral zato da bi imel ravno 10 let okvira za filme.

# %%
raw = original[original.PBay_sejalci!= 0]
raw
# Out:
#                               ime  leto  IMDB_ocena  IMBD_glasovi  \
# Id
# 0                    Interstellar  2014         8.6        843711
# 2                       Prisoners  2013         8.1        356010
# 3    Kingsman: The Secret Service  2014         7.8        357774
# 4         The Wolf of Wall Street  2013         8.2        717893
# 5                       Inception  2010         8.8       1389686
# 6         Guardians of the Galaxy  2014         8.1        615460
# 7            Inglourious Basterds  2009         8.3        834631
# 8               The Green Inferno  2013         5.5         16039
# 9                 The Dark Knight  2008         9.0       1587975
# 10                   The Departed  2006         8.5        829596
# ..                            ...   ...         ...           ...
# 990                  The Way Back  2010         7.3         84432
# 991        The Inbetweeners Movie  2011         6.8         61213
# ...

# %% [raw]
# Ker nekaterih filmov moj program ni našel na Piratebayu bom tiste odstranil z podatkov, da ne bom imel kakšnih problemov z njimi. (odstranil sem 7.1% filmov)

# %%
#Poglejmo povprečje zajetih podatkov
((100*raw.mean())//1)/100
#
# Out:
# leto              2010.18
# IMDB_ocena           6.78
# IMBD_glasovi    171744.03
# PBay_sejalci      1477.72
# PBay_pijavke       260.65
# dtype: float64

# %%
letni_pregled = raw.groupby('leto')

letni_pregled.size()
# Out:
# leto
# 2004     63
# 2005     55
# 2006     54
# 2007     59
# 2008     67
# 2009     63
# 2010     69
# 2011     92
# 2012     88
# 2013    126
# 2014    193
# dtype: int64

# %%
oc = raw['IMDB_ocena'].idxmax()
gl = raw['IMBD_glasovi'].idxmax()
se = raw['PBay_sejalci'].idxmax()
le = raw['PBay_pijavke'].idxmax()
[oc,gl,se,le]
# Out:
# [9, 9, 750, 750]

# %%
raw.loc[oc]
raw.loc[gl]
raw.loc[se]
raw.loc[le]
# Out:
# ime                 W.
# leto              2008
# IMDB_ocena         6.4
# IMBD_glasovi     40225
# PBay_sejalci    265270
# PBay_pijavke     61563
# Name: 750, dtype: object
